# %%
df=spark.read.table("databricks_catalog.bronze.regions")
df.display()

# %%
df=df.drop("_rescued_data")

# %%
df.write.format('delta')\
    .mode("overwrite")\
    .save("abfss://silver@datalakedatabricksram.dfs.core.windows.net/regions")

# %%
df=spark.read.format('delta')\
    .load("abfss://silver@datalakedatabricksram.dfs.core.windows.net/products")
df.display()

# %%
# %sql 
create table if not exists databricks_catalog.silver.regions_silver
using delta
location 'abfss://silver@datalakedatabricksram.dfs.core.windows.net/regions'
